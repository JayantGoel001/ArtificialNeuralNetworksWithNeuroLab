# %%
import numpy as np
import matplotlib.pyplot as plt
import neurolab as nl

# %%
min_vals = -20
max_vals = 20
num_points = 140

x = np.linspace(min_vals,max_vals,num_points)
y = 3*np.square(x)+5
y/=np.linalg.norm(y)

# %%
data = x.reshape(num_points,1)
labels = y.reshape(num_points,1)

plt.scatter(data,labels)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Data Points')
plt.grid()

# %%
mlnn = nl.net.newff([[min_vals,max_vals]],[10,6,1])
mlnn.trainf = nl.train.train_gd
error = mlnn.train(data,labels,epochs=2000,show=100,goal=0.01)
# Out:
# Epoch: 100; Error: 2.8658913959840566;
# Epoch: 200; Error: 1.75738440843039;
# Epoch: 300; Error: 0.7027773946794451;
# Epoch: 400; Error: 0.5551795803597197;
# Epoch: 500; Error: 0.19566124712616723;
# Epoch: 600; Error: 0.17650796937540147;
# Epoch: 700; Error: 0.17347421307366406;
# Epoch: 800; Error: 0.1167808572851082;
# Epoch: 900; Error: 0.08577514876706174;
# Epoch: 1000; Error: 0.06435374860757054;
# Epoch: 1100; Error: 0.048282689177766555;
# Epoch: 1200; Error: 0.038331219079527024;
# Epoch: 1300; Error: 0.03226765557331907;
# Epoch: 1400; Error: 0.028322269063573016;
# Epoch: 1500; Error: 0.025824430262356514;
# Epoch: 1600; Error: 0.024195283163977614;
# Epoch: 1700; Error: 0.02310174710396041;
# Epoch: 1800; Error: 0.022109406384959583;
# Epoch: 1900; Error: 0.020579422743929765;
# Epoch: 2000; Error: 0.0378593648991101;
# The maximum number of train epochs is reached

# %%
plt.plot(error)
plt.ylabel("Error")
plt.xlabel("Epochs")
plt.grid()
plt.show()

# %%
output = mlnn.sim(data)
y_pred = output.reshape(num_points)

x_dense = np.linspace(min_vals,max_vals,num_points*2)
y_dense_pred = mlnn.sim(x_dense.reshape(x_dense.size,1)).reshape(x_dense.size)

plt.plot(x_dense,y_dense_pred,'.',x,y,'*',x,y_pred,'o')
plt.title('Actual vs Predicted')
plt.grid()
plt.show()
